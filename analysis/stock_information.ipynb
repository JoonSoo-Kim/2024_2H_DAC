# %%
import yfinance as yf
import pandas as pd
import os

# 개별 ETF의 정보를 DataFrame 형태로 반환하는 함수
def get_etf_info(ticker):
    etf = yf.Ticker(ticker)
    info = etf.info

    data = {
        "ticker": ticker,
        "longName": info.get("longName", "-"),
        "currentPrice": info.get("previousClose", "-"),
        "sharesOutstanding": info.get("totalAssets", "-"),
        "52WeekHigh": info.get("fiftyTwoWeekHigh", "-"),
        "52WeekLow": info.get("fiftyTwoWeekLow", "-"),
        "benchmark": info.get("benchmark", "-"),
        "ipoDate": info.get("ipoDate", "-"),
        "expenseRatio": info.get("annualReportExpenseRatio", "-"),
        "fundManager": info.get("fundFamily", "-"),
        "navPrice": info.get("navPrice", "-"),
        "monthChange": info.get("monthlyHoldingsTurnover", "-"),
        "quarterChange": info.get("threeMonthChangePercent", "-"),
        "yearChange": info.get("sixMonthChangePercent", "-")
    }

    # monthChange, quarterChange, yearChange는 yfinance에서 제공하지 않을 수 있음. 
    # 그래서 직접 계산
    try:
        history = etf.history(period="6mo")  # 최근 6개월의 price 데이터
        if not history.empty:
            # 현재 가격
            current_price = history["Close"][-1]
            
            # monthChange
            month_ago_price = history["Close"][-22] if len(history) >= 22 else None
            data["monthChange"] = ((current_price - month_ago_price) / month_ago_price * 100) if month_ago_price else "N/A"
            
            # quarterChange
            quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
            data["quarterChange"] = ((current_price - quarter_ago_price) / quarter_ago_price * 100) if quarter_ago_price else "N/A"
            
            # yearChange
            half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
            data["yearChange"] = ((current_price - half_year_ago_price) / half_year_ago_price * 100) if half_year_ago_price else "N/A"
        else:
            data["monthChange"] = "-"
            data["quarterChange"] = "-"
            data["yearChange"] = "-"
    except Exception as e:
        print(f"오류가 발생함: {e}")
        data["monthChange"] = "-"
        data["quarterChange"] = "-"
        data["yearChange"] = "-"

    return pd.DataFrame([data])

# 폴더 안에 있는 모든 종목을 처리하여 하나의 CSV 파일에 저장하는 함수
def process_all_etfs(folder_path, output_file):
    all_data = pd.DataFrame()  # 모든 데이터를 저장할 DataFrame
    
    for filename in os.listdir(folder_path):
        # 파일 이름에서 확장자를 제외한 부분을 ticker로 사용함
        if filename.endswith(".csv"):
            ticker = filename.split(".")[0]
            print(f"Processing {ticker}...")
            etf_data = get_etf_info(ticker)
            all_data = pd.concat([all_data, etf_data], ignore_index=True)  # 데이터를 누적

    # 모든 데이터가 누적된 DataFrame을 하나의 CSV 파일로 저장
    all_data.to_csv(output_file, index=False, encoding='utf-8-sig')
    print(f"{output_file} 파일 생성 완료")

# 예시 사용법
folder_path = 'C:\\Users\\wnstj\\OneDrive\\바탕 화면\\데이터분석캡스톤디자인\\ETF_US_v4'  # ETF 종목 파일들이 저장된 폴더 경로
output_file = "all_etfs_info.csv"  # 저장할 통합 파일 이름
process_all_etfs(folder_path, output_file)
# Out:
# Processing AAXJ...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing ACWI...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing ACWV...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing ACWX...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing AFK...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing AGG...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing AGQ...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing AGZD...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing AIA...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing AMLP...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing ANGL...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing AOA...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing AOK...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing AOM...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing AOR...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing ARGT...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing ASEA...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing ASHR...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing BAB...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing BIL...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing BIV...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing BIZD...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing BKLN...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing BLV...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing BND...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing BNDX...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing BNO...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing BOIL...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing BOND...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing BRZU...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing BSV...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing BTAL...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing BWX...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# ...
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing XSMO...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing XSVM...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing XYLD...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing YANG...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing YCL...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing YINN...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing YXI...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing YYY...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing ZROZ...
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
# Processing ZSL...
# all_etfs_info.csv 파일 생성 완료
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_price = history["Close"][-1]
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month_ago_price = history["Close"][-22] if len(history) >= 22 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quarter_ago_price = history["Close"][-66] if len(history) >= 66 else None
# C:\Users\wnstj\AppData\Local\Temp\ipykernel_1664\902352247.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   half_year_ago_price = history["Close"][0] if len(history) >= 126 else None
